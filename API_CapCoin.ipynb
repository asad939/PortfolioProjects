# %%
# Extracting Apis from CAp coinwebsite using python and saving it as text file 


import requests
import pandas as pd 
from prettytable import PrettyTable 
import json

# %%
# Creating prettytable object 

tableobj = PrettyTable ()

KeyVal = '97589b65-d8c9-46cf-be14-ef22c6333fae'

# %%
# link for api end point data  PLUS KEY

api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=97589b65-d8c9-46cf-be14-ef22c6333fae'

# %%
json_data = requests.get(api_endpoint).json()

# %%
cryptodata = json_data['data']

# %%
requests.get(api_endpoint).json()
# Out:
# {'status': {'timestamp': '2021-12-23T13:01:28.289Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 51,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 8504},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 8092,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
# ...

# %%
# Fetching data with for loop and saving in prettytable 

for currency in cryptodata:
    curr_name = currency['name']
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h']
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    tableobj.add_row([curr_name,curr_price,curr_change_1h, curr_change_24h, curr_change_7d])

# %%
 tableobj.field_names = ["Currency Name", 
                         "Currency Price","Currency Change 1h","Currency Change 24h","Currency Change 7d"]

# %%
print(tableobj)
# Out:
# +-----------------------+------------------------+--------------------+---------------------+--------------------+
# |     Currency Name     |     Currency Price     | Currency Change 1h | Currency Change 24h | Currency Change 7d |
# +-----------------------+------------------------+--------------------+---------------------+--------------------+
# |        Bitcoin        |    48674.9246109302    |     0.51648253     |      0.13405632     |    -0.08726132     |
# |        Ethereum       |   3949.4057893971285   |     0.24664456     |     -0.11327328     |    -2.23536675     |
# |      Binance Coin     |   529.5923902125473    |     0.42656598     |     -0.04526031     |    -1.59493328     |
# |         Tether        |   1.000355003584729    |    -0.00014111     |      0.02740721     |    -0.07617211     |
# |         Solana        |   179.05053535274374   |    -0.19588114     |     -1.74153276     |    -3.20120937     |
# ...

# %%
#SAVING DATA IN TXT FILE

table_txt = tableobj.get_string()
with open ('output.txt', 'w')as file:
    file.write(table_txt)
